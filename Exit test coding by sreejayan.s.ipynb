# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read dataset train to data

# %%
 data=pd.read_csv(r"C:\Users\Documents\Desktop\dataset exit\train.csv")

# %% [markdown]
# # Display the data set "train .csv"

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %% [markdown]
# # Display detailed decription about dataset

# %%
data.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# ...

# %% [markdown]
# # Print the null values in data set

# %%
data.isnull().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                       417
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                  552
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                     125
# years_of_experience          144
# ...

# %%
data.shape
# Out:
# (13994, 30)

# %%
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %% [markdown]
# # Display the information about data set

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13994 entries, 0 to 13993
# Data columns (total 30 columns):
# player_id                    13994 non-null object
# name                         13994 non-null object
# age                          13994 non-null int64
# gender                       13975 non-null object
# country                      13994 non-null object
# height                       13994 non-null object
# weight                       13577 non-null object
# ball_controlling_skills      13581 non-null float64
# body_reflexes                13994 non-null float64
# body_balance                 13994 non-null float64
# jumping_skills               13970 non-null float64
# penalties_conversion_rate    13964 non-null float64
# mental_strength              13966 non-null float64
# goalkeeping_skills           13994 non-null float64
# defending_skills             13994 non-null float64
# passing_skills               13994 non-null float64
# ...

# %%
#plot of age

# %%
# Visualizations
# Distribution of Age
plt.figure(figsize=(8, 6))
sns.distplot(data['age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(16,7))

plt.subplot(2,2,1)
sns.distplot(data['age'],color='DeepPink')

plt.show()

# %%
# Distribution of Gender
plt.figure(figsize=(6, 4))
sns.countplot(data['gender'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of Countries
plt.figure(figsize=(15, 6))
sns.countplot(data['country'], order=data['country'].value_counts().index)
plt.title('Distribution of Countries')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Correlation Heatmap
corr_matrix = data.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
# Plot histograms for numerical variables
data.hist(bins=10, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# Select numerical attributes for the pair plot
numerical_attributes = [
    'age', 'ball_controlling_skills', 'body_reflexes', 'body_balance',
    'height', 'weight', 'behaviour_rating', 'matches_played',
    'fitness_rating', 'trophies_won', 'dedication_level',
    'coaching', 'years_of_experience', 'no_of_disqualifications'
]

# Create a pair plot
sns.set(style="ticks")
sns.pairplot(data[numerical_attributes])
plt.suptitle("Pair Plot of Football Player Attributes", y=1.02)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# Check the distribution of the target class
plt.figure(figsize=(6, 4))
sns.countplot(data['selection'])
plt.title('Distribution of Selection (Target Class)')
plt.xlabel('Selection')
plt.ylabel('Count')
plt.show()

# %%
# Visualize numerical features by target class
numerical_attributes = [
    'age', 'ball_controlling_skills', 'body_reflexes', 'body_balance',
    'behaviour_rating', 'matches_played',
    'fitness_rating', 'trophies_won', 
     'years_of_experience'
]
for attribute in numerical_attributes:
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='selection', y=attribute, data=data)
    plt.title(f'{attribute} by Selection')
    plt.xlabel('Selection')
    plt.ylabel(attribute)
    plt.show()

# %%
# Visualize categorical features by target class
categorical_attributes = ['gender', 'country', 'strong_foot']

for attribute in categorical_attributes:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=attribute, hue='selection', data=data)
    plt.title(f'{attribute} by Selection')
    plt.xlabel(attribute)
    plt.ylabel('Count')
    plt.legend(title='Selection')
    plt.xticks(rotation=45)
    plt.show()

# %%
data.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
data.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# ...

# %%
#Barplot of name and age of players
data.groupby('name')[['ball_controlling_skills','body_reflexes','strong_foot']].mean().plot(kind='bar')
plt.show()

# %% [raw]
# sns.pairplot(data=data[['name', 'age', 'gender','country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection']])
# plt.title('player related for slection')

# %%
# Visualize categorical features by target class
categorical_attributes = ['gender', 'country', 'strong_foot']

for attribute in categorical_attributes:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=attribute, hue='selection', data=data)
    plt.title(f'{attribute} by Selection')
    plt.xlabel(attribute)
    plt.ylabel('Count')
    plt.legend(title='Selection')
    plt.xticks(rotation=45)
    plt.show()

# %% [raw]
#  # Create a bar plot of country-wise selection
# plt.figure(figsize=(12, 6))
# sns.countplot(x='country', hue='selection', data=data)
# plt.title('Country-wise Selection')
# plt.xlabel('Country')
# plt.ylabel('Count')
# plt.legend(title='Selection', labels=['Not Selected', 'Selected'])
# plt.xticks(rotation=90)
# plt.show()
